# %%
import pandas as pd
# %matplotlib inline

# %%
shootings = pd.read_csv('./shootings.tsv', delimiter='\t')
shootings.head()
# Out:
#    year  events  deaths  injuries
# 0  1764       1      10         2
# 1  1840       1       1         0
# 2  1853       1       1         0
# 3  1856       1       2         0
# 4  1858       1       1         0

# %%
shootings[1:].plot(kind='bar', x='year', y=['deaths', 'injuries'], figsize=(16, 6))

# %%
shootings[-40:].plot(kind='bar', x='year', y=['deaths', 'injuries'], figsize=(16, 6))
